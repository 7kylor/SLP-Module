# %%
# class NoteCatalog:
#     def __init__(self):
#         self.note_details = {}
    
#     def add_note(self, title, Id):
#         self.note_details[Id] = title
#         print ((f"Note {title} with Id {Id} is added to the notes"))
        
#     def get_note_by_Id(self, Id):
#         if Id in self.note_details:
#             return self.note_details[Id]
#         else:
#             return "note with + {Id} + not found"

# def main():
#     notes = NoteCatalog()
    
#     while True:
#         print("1. Add New note")
#         print("2. Get a note by id")
#         print("3. Exit")
#         choice =  (input("Enter your choice: "))
#         if choice ==   "1":
#             title = input("Enter the note title: ")
#             Id = input("Enter the note id: ")
#             notes.add_note(title, Id)
            
#         elif choice ==   "2":
#             Id =  ((input("Enter Note id")))
#             title =  notes.get_note_by_Id(Id)
#             print(f"the note your looking for is {title}")  
#         elif choice ==  "3":
#             break
#         else:
#             print("Invalid choice. Try again.")
#             continue
        
        
# if __name__ == "__main__":
#     main()





# class MusicLibrary:
#     def __init__(self):
#         self.music_details  = {}
        
#     def add_music(self, Id, author):
#         self.music_details[Id] = author
#         print(f"Music wit h id {Id} is added to the library")
        
#     def get_music_by_id(self, Id):
#         if Id in self.music_details:
#             return self.music_details[Id]
#         else:
#             return "Music with id {Id} not found"
    
    
# def main():
#     music_library = MusicLibrary()
    
#     while True:
#         print("Menu")
#         print("1. Add Music")
#         print("2. Get Music")
#         print("3. Exit")
        
#         choice = input("Enter your choice: ")
#         if choice =="1":
#             song_id = input("enter song id")
#             song_author = input("enter song author")
#             music_library.add_music(song_id, song_author)
#         elif choice == "2":
#             song_id = input("Enter the id of the song")
#             music_library.get_music_by_id(song_id)
#         elif choice == "3":
#             print("Goodby")
#             break 
#         else:
#             print("Try again")

# if __name__ == "__main__":
#     main()
# Out:
# Menu
# 1. Add Music
# 2. Get Music
# 3. Exit
# Music wit h id 1 is added to the library
# Menu
# 1. Add Music
# 2. Get Music
# 3. Exit
# Menu
# 1. Add Music
# 2. Get Music
# 3. Exit
