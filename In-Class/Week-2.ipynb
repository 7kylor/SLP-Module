# %%
import math
from datetime import datetime

a = 2+4
print (a)


# week 2 exercise 

#1
print(math.sqrt(32))

#2
print(datetime.now())

#3 
a=4
b=6.7
c="name"

t = !true 

print(a+b)

#4
n = "Al Baraa"

n.swapcase()
n.upper()
n.lower()


f"my name is {n}"
# Out:
# 6
# 5.656854249492381
# 2024-03-12 15:29:54.030638
# 10.7
# 'my name is Al Baraa'
