# %%
import math
from datetime import datetime

a = 2+4
print (a)


# week 2 exercise 

#1
print(math.sqrt(32))

#2
print(datetime.now())

#3 
a=4
b=6.7
c="name"

t = True

print(a+b)

#4
n = "Al Baraa"

n.swapcase()
n.upper()
n.lower()


f"my name is {n}"


age=17
if age >= 18:
    print("adult")
else:
    print("minor")
    
 
# userInput = input("test user input ")
# print(userInput)

    # functions : def
    
    m = lambda x  , y , z : x * y - z
    print(m(3,4,8))


    v= lambda x  , y  : x * y - 5
    print(v(3,4)-2 * m(3,4,5))
# Out:
# 6
# 5.656854249492381
# 2024-03-19 14:32:18.548381
# 10.7
# minor
# 4
# -7
